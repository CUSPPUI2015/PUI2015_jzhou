# %% [markdown]
# # I want you to create a <i>reproducible research</i> code
# that means we want the reader to be able to reproduce every step of our analysis. when stochastic processes and random variables are involved that gets tricky, but since computers are unable to rpoduce truly random numbers, we can actually reproduce every series of "pseudo random" number generated by a computer as long as we know what seed is used. <i>The first seed will determin entirely the distribution that is generated, and the seeds of the following distriburions generated by the code!</i>

# %%
import os
import sys

# %% [markdown]
# #THIS IS THE MOST IMPORTANT PIECE OF THIS CODE!
# ##we must give numpy as seed for this code to be reproducible
# http://docs.scipy.org/doc/numpy/reference/generated/numpy.random.seed.html

# %%
import numpy as np
np.random.seed(seed=127)

# %% [markdown]
# ##use this function to generate 100 2-dimensional random datapoints in a gaussian distribution in 2 dimensions
#
# http://docs.scipy.org/doc/numpy/reference/generated/numpy.random.randn.html

# %%
a=np.random.randn(100,2)
print a
# Out:
# [[-0.57180948  0.02962396]
#  [ 0.56259194 -0.64765191]
#  [-0.84543614  0.10656535]
#  [ 1.73239225 -0.47101679]
#  [-0.32422731  2.03643196]
#  [-0.5866708   0.20484442]
#  [ 0.89399702 -0.08794463]
#  [ 0.24721895 -0.75498723]
#  [ 0.37346569 -0.20968508]
#  [-1.05862372  0.61330042]
#  [-1.59792277 -0.11023729]
#  [-0.5998517   1.13544163]
#  [ 0.1163373   0.52661021]
#  [ 1.61392509 -1.2572433 ]
#  [-0.2229602   0.2857268 ]
#  [-1.4452435   1.87320964]
#  [-0.4799677  -0.42481417]
#  [-0.53858862 -0.01493984]
#  [ 1.06413515 -0.26519843]
#  [-1.42272456 -0.57073876]
#  [ 0.49219664 -0.8358641 ]
#  [-1.30295143  0.09587726]
#  [ 1.78730813 -0.56892778]
#  [ 1.85095436  0.12032429]
#  [-0.95172496 -1.33694516]
#  [ 1.1088666  -0.94633305]
#  [-0.48359925 -0.59830998]
#  [-0.33596381 -0.39244161]
#  [-1.77292678  0.03926891]
#  [-0.73770675 -1.22462715]
#  [ 2.02022416  0.02761417]
#  [-1.04595813 -1.18151699]
#  [-0.28268098  0.10964912]
#  [-0.24177327  1.81965634]
#  [ 0.09999651  2.25421001]
#  [-0.3019104  -1.17990837]
#  [ 1.75969755 -0.89623973]
#  [ 0.72476206  0.60691811]
#  [-1.2016595   1.08075256]
#  [-0.57982839 -0.66247061]
#  [-0.59118362 -0.80887231]
#  [-0.40399896  0.24761121]
#  [ 0.26731844 -1.69388816]
#  [-1.48851348  0.66860075]
#  [ 1.32036874  0.82582194]
#  [-0.05621504  0.29309126]
#  [-1.50742176  1.13022814]
#  [ 0.3000804   0.78015486]
#  [-0.89956734  1.61010461]
#  [-0.13015743 -0.53783328]
#  [ 0.62227046 -0.39671911]
#  [-0.04470027  0.53361812]
#  [ 0.76747858 -0.88138889]
#  [-0.12836288  0.4927121 ]
#  [-0.35031846 -0.34808493]
#  [ 0.93513509 -0.55454534]
#  [ 0.81929777  0.48937102]
#  [ 0.05603232  0.67035054]
#  [ 0.52965206 -0.4403011 ]
#  [-1.13630862 -0.43485892]
#  [-0.90926443 -0.17866185]
#  [ 0.96973943  0.72441173]
#  [-0.14117253 -1.33557728]
#  [ 0.72749376  0.87810342]
#  [-0.76499008 -0.02737989]
#  [-0.41975406 -0.1524274 ]
#  [-0.34985348 -1.49325117]
#  [-1.10819761 -1.33163267]
#  [ 0.26745799 -0.25888093]
#  [ 0.9336979  -1.41195969]
#  [ 0.87145572  0.6508002 ]
#  [ 1.18720424 -0.90038854]
#  [ 2.37512473  0.45119497]
#  [-0.8553192  -0.16968424]
#  [ 0.23793671 -0.52267555]
#  [ 0.12027198  2.13552034]
#  [-0.44349805  2.35858101]
#  [ 0.50666773 -0.31207048]
#  [-1.31584766  0.55069033]
#  [-1.02932634  1.99062966]
#  [ 0.91839073 -0.72301794]
#  [ 0.1622014   0.68893674]
#  [-1.68290101  0.38272608]
#  [ 1.34935262 -0.6447041 ]
#  [-0.41599098 -0.33812636]
#  [ 0.64119336 -0.27924479]
#  [-0.88088668  0.9179682 ]
#  [ 0.60730309 -0.64097149]
#  [ 0.37833141  0.35745964]
#  [-0.43866962 -1.20888412]
#  [-0.32227759  0.62014869]
#  [-1.66258389 -0.26180387]
#  [ 1.27186239 -0.52725331]
#  [-0.67803452  0.82195905]
#  [ 0.21363179 -0.53926839]
#  [ 0.00991074  0.62922317]
#  [ 1.35101551  1.47345468]
#  [-0.01982192 -0.75327709]
#  [ 1.1214244   0.08115445]
#  [-0.65000942 -0.16067385]]

# %% [markdown]
# ## use the same function to generate 50 more random objects, but this time change the mean
# to do that you multiply the distribution by a different sigma, and add your new mean - remember that these are 2D objects, so yor mean must be a 2D vector (a list, an array or a tuple)!

# %%
b=1.4*np.random.randn(50,2) + (3,3)
print b
# Out:
# [[ 5.03483506  3.68153112]
#  [-0.62051183  0.88973635]
#  [ 5.49024415  4.91856787]
#  [ 2.75762257  4.06928835]
#  [ 3.40364802  2.84264955]
#  [ 1.06338958  2.6671023 ]
#  [ 4.64795553  3.17048707]
#  [ 4.18916668  2.18492467]
#  [ 3.31547605  3.49467151]
#  [ 1.86941812  2.82299784]
#  [ 1.14648355  2.9277654 ]
#  [ 2.28413655  1.27815247]
#  [ 4.42812389  1.29716477]
#  [ 2.30918161  1.55082478]
#  [ 2.73547717  4.30117692]
#  [ 2.53720923  2.46756492]
#  [ 3.19033359  2.93067619]
#  [ 2.24964661 -0.39949166]
#  [ 3.9944945   5.00515828]
#  [ 1.95820049  1.85884605]
#  [ 3.08118712  3.30870661]
#  [ 4.14658014  3.28188344]
#  [ 2.29786296  0.68730849]
#  [ 4.52586283  2.32194349]
#  [ 0.71786719  2.36476485]
#  [ 1.57684053  3.28926735]
#  [ 2.50246769  3.11037089]
#  [ 2.31627723  2.95371747]
#  [ 3.44313743  3.16072534]
#  [ 1.42961072  4.21069023]
#  [ 2.75516189  1.78590671]
#  [ 3.47329965 -0.61792334]
#  [ 2.54457495  2.21840255]
#  [ 3.74287976  1.54955737]
#  [ 2.02418126  0.61910499]
#  [ 3.4599872   5.25609084]
#  [ 1.8576569   1.61609664]
#  [ 2.62524096  2.83538667]
#  [ 2.90398958  3.61162519]
#  [ 2.44678221  3.40820137]
#  [ 3.73826519  1.92090581]
#  [ 4.06055406  2.40284205]
#  [ 5.33213497  3.03573982]
#  [ 3.02384441  3.31590477]
#  [ 2.23962207  1.44877021]
#  [ 3.98797417  1.94549943]
#  [ 4.5371322   1.72020707]
#  [ 3.92055076  1.34553106]
#  [ 5.3758547   5.38246791]
#  [ 4.25844353  1.50557601]]

# %% [markdown]
# ##now plot them with this function:
#
# https://scipy-lectures.github.io/intro/matplotlib/matplotlib.html#scatter-plots
#
# ##if you print the array it will be a 2x100: 100 2D objects. although that is what we wanted we cannot plot it easily this way: there are many ways to deal with it. the goal is to pass the first dimension as the disrt argument to scatter, and the second dimension as the second argument. i am gonna do it by transposing the array (switching the axes)

# %%
a1=a.T
b1=b.T

# %%
import pylab as pl 
# %matplotlib inline
pl.scatter(a1[0],a1[1])
pl.scatter(b1[0],b1[1])

# %% [markdown]
# ##first plot them as a single distribution, then change the color for the 2 samples
#
# remember to give your labels some names and to make a legend! in the legend tell me what the mean and standard deviation of each sample is

# %%
pl.scatter(a1[0],a1[1],color='red',label='N(0,0)')
pl.scatter(b1[0],b1[1],color="blue",label='N(3,1.4)')
pl.legend(loc='best')
